# %% [markdown]
# # Actividad
# | Nombre  | Matrícula |
# |---------|-----------|
# | Josephine Esposito | A00827145 |
# | Mauricio Maqueo Huerta | A01620649 |
# | Guillermo Tafoya Milo| A01633790 |

# %% [markdown]
# # Entregar
# Archivo PDF de la actividad y la liga de la actividad en su repostitorio.
#
# # Nota:
# Las tareas 1 a la 5 se califican como entregadas o no entregadas.
#
# Al integrante que no participe en la actividad no se le tomará en cuenta para la calificación.
#
# El límite para entregar las actividades es el viernes antes de las 23:59.

# %% [markdown]
# 1. Leer el archivo **netflix_titles.csv**

# %%
#Read netflix_titles.csv into a DataFrame called netflix.
dataPath = './data/'
import pandas as pd
netflix = pd.read_csv(dataPath + 'netflix_titles.csv')

# %% [markdown]
# 2. Observa las primeras líneas usando la función head

# %%
#Print the first five rows of the DataFrame.
netflix.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# ...

# %% [markdown]
# 3. Genera una función que despliegue el primer reglon del archivo.

# %%
def top_uno():
  ## Return only the first row of netflix.
  return netflix.head(1)
top_uno()
# Out:
#   show_id     type title director  \
# 0      s1  TV Show    3%      NaN
#
#                                                 cast country       date_added  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil  August 14, 2020
#
#    release_year rating   duration  \
# 0          2020  TV-MA  4 Seasons
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
#
#                                          description
# 0  In a future where the elite inhabit an island ...

# %% [markdown]
# 4. Genera una función que regrese el número de registros del archivo

# %%
def row_number():
  ## Return the number of rows in netflix.
  return netflix.shape[0]
row_number()
# Out:
# 7787

# %% [markdown]
# 5. Generar una función que entregue las películas con release_year del 2020

# %%
year_consulta=2020
def released_year(year):
  ## Return the rows in netflix where the release_year is equal to year.
  return netflix[netflix['release_year']==year]
released_year(year_consulta)
# Out:
#      show_id     type                                title           director  \
# 0         s1  TV Show                                   3%                NaN
# 24       s25  TV Show  ​SAINT SEIYA: Knights of the Zodiac                NaN
# 26       s27  TV Show                             (Un)Well                NaN
# 27       s28    Movie                               #Alive             Cho Il
# 29       s30  TV Show                             #blackAF                NaN
# ...      ...      ...                                  ...                ...
# 7725   s7726  TV Show                      You Cannot Hide                NaN
# 7734   s7735    Movie                      You've Got This  Salvador Espinosa
# 7738   s7739  TV Show                      Young Wallander                NaN
# 7741   s7742    Movie            Your Name Engraved Herein      Liu Kuang-hui
# 7744   s7745    Movie          Yours Sincerely, Kanan Gill       Neville Shah
#
# ...

# %% [markdown]
# 6. Películas con la columna de contry='Mexico'

# %%
pais_consulta='Mexico'
def country_year(pais_consulta):
  ## Return the rows in netflix where the country is equal to pais_consulta.
  return netflix[netflix['country']==pais_consulta]
country_year(pais_consulta)
# Out:
#      show_id     type                                           title  \
# 1         s2    Movie                                            7:19
# 12       s13  TV Show                                            1994
# 292     s293    Movie                             Acapulco La vida va
# 370     s371    Movie                  Alan Saldaña: Mi vida de pobre
# 378     s379    Movie  Alex Fernández: The Best Comedian in the World
# ...      ...      ...                                             ...
# 7698   s7699  TV Show                                          Yankee
# 7725   s7726  TV Show                                 You Cannot Hide
# 7734   s7735    Movie                                 You've Got This
# 7773   s7774    Movie                                  Zoé: Panoramas
# 7779   s7780  TV Show                                       Zona Rosa
#
#                                    director  \
# 1                         Jorge Michel Grau
# ...

# %% [markdown]
# **Ejercicio de apply**
#
# Genrar una función que obtenga el cuadrado de un número y llamala cuadrado.

# %%
def cuadrado(x):
    # Return the square of x.
    return x**2
cuadrado(2)
# Out:
# 4

# %% [markdown]
# Usando la instruccion **apply** generar el cuadrado de todos los valores del siguiente dataframe.
#
# Ultiliza la función que definiste en el paso anterior.

# %%
import pandas as pd
df = pd.DataFrame({'A': [1, 2, 3, 5, 6], 'B': [10, 20, 30, 40, 50]})
# Using apply() to square all values in a column
df['A'].apply(cuadrado)
df
# Out:
#    A   B
# 0  1  10
# 1  2  20
# 2  3  30
# 3  5  40
# 4  6  50

# %% [markdown]
# **Ejercicio de map**
#
# Calcular la longitud del contenido de todas las celdas del datafame usando **lambda** y la operación **map**

# %%
import pandas as pd
df = pd.DataFrame({'Nombre': ['Luz', 'Eunice','Ignacio','José'], 'Apellido': ['Angeles', 'Ochoa','Treviño','Zapata']})
# Using map() to square all length values in a column
df = df.applymap(lambda x: cuadrado(len(x)))
df
# Out:
#    Nombre  Apellido
# 0       9        49
# 1      36        25
# 2      49        49
# 3      16        36

# %% [markdown]
# # Guardar el resultado como pdf

# %% [markdown]
# [Liga al repositorio del equipo 4](https://github.com/ltchycrane/Semana_Tec)

# %% [markdown]
# * Exporta el notebook a formato HTML.

# %%
# Save notebook as HTML file
! jupyter nbconvert "3.3 - Actividad - Lectura Datos - Pandas.ipynb" --to html
# Out:
# "jupyter" no se reconoce como un comando interno o externo,
# programa o archivo por lotes ejecutable.

# %% [markdown]
# * Haz doble clic en el archivo nuevo que se creó dentro de la carpeta `arte-analitica` y en la parte superior derecha dale clic en **imprimir**
#
# * Imprime el archivo como *PDF* y súbelo a Canvas.
